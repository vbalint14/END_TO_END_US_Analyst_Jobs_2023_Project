# %%
import pandas as pd
df=pd.read_csv('data_jobs_cleaned.csv')

# %%
df=df[(df['job_location']!='Anywhere') & (df['job_location']!='United States')]

# %%
df['job_location'] = df['job_location'].str.split(',', expand=True)[0].str.strip()
df
# Out:
#         job_id       job_title_short  \
# 0            0  Senior Data Engineer
# 1            1          Data Analyst
# 2            2         Data Engineer
# 3            3         Data Engineer
# 4            4         Data Engineer
# ...        ...                   ...
# 508037  785735  Senior Data Engineer
# 508038  785736     Software Engineer
# 508039  785737          Data Analyst
# 508040  785738      Business Analyst
# 508041  785740     Software Engineer
#
#                                                 job_title job_location  \
# 0       Senior Clinical Data Engineer / Principal Clin...    Watertown
# 1                                            Data Analyst  Guadalajara
# 2       Data Engineer/Scientist/Analyst, Mid or Senior...       Berlin
# 3       LEAD ENGINEER - PRINCIPAL ANALYST - PRINCIPAL ...  San Antonio
# 4                                  Data Engineer- Sr Jobs   Washington
# ...                                                   ...          ...
# 508037                               Senior Data Engineer       Berlin
# 508038                                    DevOps Engineer    Singapura
# 508039                                   CRM Data Analyst   Bad Rodach
# 508040                     Commercial Analyst - Start Now     Malaysia
# 508041                                 AWS System Analyst        India
#
#                            job_via job_schedule_type  job_work_from_home  \
# 0                  via Work Nearby         Full-time               False
# 1                 via BeBee México         Full-time               False
# 2                     via LinkedIn         Full-time               False
# 3                via Diversity.com         Full-time               False
# 4               via Clearance Jobs         Full-time               False
# ...                            ...               ...                 ...
# 508037  melalui Top County Careers   Pekerjaan tetap               False
# 508038         melalui Trabajo.org   Pekerjaan tetap               False
# 508039   melalui BeBee Deutschland   Pekerjaan tetap               False
# 508040            melalui Ricebowl   Pekerjaan tetap               False
# 508041              melalui Trigyn   Pekerjaan tetap               False
#
#              search_location      job_posted_date  job_no_degree_mention  \
# 0       Texas, United States  2023-06-16 13:44:15                  False
# 1                     Mexico  2023-01-14 13:18:07                  False
# 2                    Germany  2023-10-10 13:14:55                  False
# 3       Texas, United States  2023-07-04 13:01:41                   True
# 4                      Sudan  2023-08-07 14:29:36                  False
# ...                      ...                  ...                    ...
# 508037               Germany  2023-03-13 06:19:07                  False
# 508038             Singapore  2023-03-13 06:16:16                  False
# 508039               Germany  2023-03-12 06:18:18                  False
# 508040              Malaysia  2023-03-12 06:32:36                  False
# 508041                 India  2023-03-13 06:16:31                  False
#
#         job_health_insurance    job_country salary_rate  salary_year_avg  \
# 0                      False  United States         NaN         115000.0
# 1                      False         Mexico         NaN         115000.0
# 2                      False        Germany         NaN         115000.0
# 3                      False  United States         NaN         115000.0
# 4                      False          Sudan         NaN         115000.0
# ...                      ...            ...         ...              ...
# 508037                 False        Germany         NaN         115000.0
# 508038                 False      Singapore         NaN         115000.0
# 508039                 False        Germany         NaN         115000.0
# 508040                 False       Malaysia         NaN         115000.0
# 508041                 False          India         NaN         115000.0
#
#         salary_hour_avg                        company_name  \
# 0                 45.98                Boehringer Ingelheim
# 1                 45.98          Hewlett Packard Enterprise
# 2                 45.98            ALPHA Augmented Services
# 3                 45.98        Southwest Research Institute
# 4                 45.98                     Kristina Daniel
# ...                 ...                                 ...
# 508037            45.98                            Pure App
# 508038            45.98  CAREERSTAR INTERNATIONAL PTE. LTD.
# 508039            45.98                    HABA FAMILYGROUP
# 508040            45.98               Lendlease Corporation
# 508041            45.98                              Trigyn
#
#                                                job_skills  \
# 0                                                     NaN
# 1       ['r', 'python', 'sql', 'nosql', 'power bi', 't...
# 2       ['python', 'sql', 'c#', 'azure', 'airflow', 'd...
# 3       ['python', 'c++', 'java', 'matlab', 'aws', 'te...
# 4       ['bash', 'python', 'oracle', 'aws', 'ansible',...
# ...                                                   ...
# 508037  ['sql', 'python', 'bigquery', 'aws', 'airflow'...
# 508038  ['bash', 'python', 'perl', 'linux', 'unix', 'k...
# 508039                     ['sas', 'sas', 'sql', 'excel']
# 508040                            ['powerpoint', 'excel']
# 508041                                    ['aws', 'flow']
#
#                                           job_type_skills
# 0                                                     NaN
# 1       {'analyst_tools': ['power bi', 'tableau'], 'pr...
# 2       {'analyst_tools': ['dax'], 'cloud': ['azure'],...
# 3       {'cloud': ['aws'], 'libraries': ['tensorflow',...
# 4       {'cloud': ['oracle', 'aws'], 'other': ['ansibl...
# ...                                                   ...
# 508037  {'cloud': ['bigquery', 'aws'], 'libraries': ['...
# 508038  {'os': ['linux', 'unix'], 'other': ['kubernete...
# 508039  {'analyst_tools': ['sas', 'excel'], 'programmi...
# 508040         {'analyst_tools': ['powerpoint', 'excel']}
# 508041              {'cloud': ['aws'], 'other': ['flow']}
#
# [457005 rows x 18 columns]

# %%
# Summarizing the frequency of job locations in job postings
df_us_job_counts=(df[(df['job_title_short']=='Data Analyst') & (df['job_country']=='United States')]
.groupby('job_location')
.size()
.sort_values(ascending=False)
.head(15)
)
df_us_job_counts=df_us_job_counts.reset_index(name='count')
df_us_job_counts
# Out:
#      job_location  count
# 0        New York   2168
# 1         Atlanta   1711
# 2         Chicago   1440
# 3          Austin   1224
# 4          Dallas   1154
# 5      Washington   1092
# 6       Charlotte    842
# 7     Los Angeles    831
# 8           Tampa    814
# 9   San Francisco    700
# 10         Boston    652
# 11         Irving    521
# 12    San Antonio    493
# 13      Arlington    444
# 14   Jacksonville    438

# %%
# Saving the filtered dataframe to a csv file
df_us_job_counts.to_csv('1_data_jobs_location_counts.csv', index=False)
